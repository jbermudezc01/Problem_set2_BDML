# %%
import geopandas
import os
import missingno as msno

# %%
ruta = '/Users/macbookair/Documents/GitHub/Problem_set2_BDML'
os.getcwd()
os.chdir(ruta)

# %% [markdown]
# El proposito de este cuaderno es agregar la variable área construida a la base de datos para mejorar nuestras predicciones
#
# Aquí se puede encontrar el diccionario de los datos abiertos de Bogotá: https://www.ideca.gov.co/sites/default/files/RCAreaConstrResid.pdf

# %%
url = '/Users/macbookair/Documents/GitHub/Problem_set2_BDML/stores/'
bog_hogares = geopandas.read_file(url+'aconstruidaresidencial.gpkg')

# %%
bog_hogares.head()
# Out:
#    OBJECTID  MANCODIGO  AREA_RESID         ANO    SHAPE_AREA  SHAPE_LEN
# 0        16  001345032      407.11  2022-01-01  8.207135e-08   0.001191  \
# 1        17  004637053     1655.09  2022-01-01  1.382929e-07   0.001711
# 2        18  002611049     1615.20  2022-01-01  7.151772e-08   0.001114
# 3        19  002430016     5272.12  2022-01-01  2.070219e-07   0.002287
# 4        20  001355039      800.45  2022-01-01  4.379187e-08   0.000901
#
#                                             geometry
# 0  MULTIPOLYGON (((-74.09371 4.51030, -74.09371 4...
# 1  MULTIPOLYGON (((-74.19504 4.62968, -74.19510 4...
# 2  MULTIPOLYGON (((-74.10655 4.49872, -74.10665 4...
# 3  MULTIPOLYGON (((-74.16554 4.57309, -74.16559 4...
# 4  MULTIPOLYGON (((-74.09661 4.55380, -74.09671 4...

# %%
bog_hogares.shape
# Out:
# (74199, 7)

# %%
bog_hogares.plot(markersize = .5)
# Out:
# <Axes: >

# %%
base_tratada = geopandas.read_file(ruta+'/stores/base_datos_tratada.csv')

# %%
base_tratada.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 48930 entries, 0 to 48929
# Data columns (total 55 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   type_data                   48930 non-null  object
#  1   property_id                 48930 non-null  object
#  2   price                       48930 non-null  object
#  3   month                       48930 non-null  object
#  4   year                        48930 non-null  object
#  5   surface_total               48930 non-null  object
#  6   surface_covered             48930 non-null  object
#  7   rooms                       48930 non-null  object
#  8   bedrooms                    48930 non-null  object
#  9   bathrooms                   48930 non-null  object
#  10  property_type               48930 non-null  object
#  11  lat                         48930 non-null  object
#  12  lon                         48930 non-null  object
#  13  description                 48930 non-null  object
#  14  log_price                   48930 non-null  object
#  15  piso_info                   48930 non-null  object
#  16  piso_numerico               48930 non-null  object
#  17  vigilancia                  48930 non-null  object
#  18  parqueadero                 48930 non-null  object
#  19  terraza                     48930 non-null  object
#  20  ascensor                    48930 non-null  object
#  21  deposito                    48930 non-null  object
#  22  cocina_integral             48930 non-null  object
#  23  piso_laminado               48930 non-null  object
#  24  distancia_restaurante       48930 non-null  object
#  25  distancia_parques           48930 non-null  object
#  26  distancia_estaciones_tp     48930 non-null  object
#  27  distancia_mall              48930 non-null  object
#  28  distancia_ciclovias         48930 non-null  object
#  29  distancia_centro_servicios  48930 non-null  object
#  30  distancia_parques2          48930 non-null  object
#  31  distancia_restaurante2      48930 non-null  object
#  32  distancia_estaciones_tp2    48930 non-null  object
#  33  distancia_mall2             48930 non-null  object
#  34  distancia_ciclovia2         48930 non-null  object
#  35  distancia_servicios2        48930 non-null  object
#  36  distancia_parques3          48930 non-null  object
#  37  distancia_restaurante3      48930 non-null  object
#  38  distancia_estaciones_tp3    48930 non-null  object
#  39  distancia_mall3             48930 non-null  object
#  40  distancia_ciclovia3         48930 non-null  object
#  41  ditancia_servecios3         48930 non-null  object
#  42  distancia_parques4          48930 non-null  object
#  43  distancia_restaurante4      48930 non-null  object
#  44  distancia_estaciones_tp4    48930 non-null  object
#  45  distancia_mall4             48930 non-null  object
#  46  distancia_ciclovia4         48930 non-null  object
#  47  ditancia_servecios4         48930 non-null  object
#  48  distancia_parques5          48930 non-null  object
#  49  distancia_restaurante5      48930 non-null  object
#  50  distancia_estaciones_tp5    48930 non-null  object
#  51  distancia_mall5             48930 non-null  object
#  52  distancia_ciclovia5         48930 non-null  object
#  53  ditancia_servecios5         48930 non-null  object
#  54  geometry                    0 non-null      geometry
# dtypes: geometry(1), object(54)
# memory usage: 20.5+ MB

# %%
from shapely.geometry import Point
#Geometrias tipo punto

base_tratada['geometry'] = base_tratada.apply(lambda row: Point(row['lon'], row['lat']), axis = 1)
base_tratada = geopandas.GeoDataFrame(base_tratada, geometry = 'geometry')

# %%
base = geopandas.sjoin(base_tratada, bog_hogares, how = 'inner', op = 'within')
#inner: conserva las observaciones de las dos bases que tengan coincidencia espacial
#within: encuentra puntos que se encuentran dentro de los poligonos de la base Bogota
#leer documentacion de within
# Out:
# /Users/macbookair/Library/Python/3.10/lib/python/site-packages/IPython/core/interactiveshell.py:3373: FutureWarning: The `op` parameter is deprecated and will be removed in a future release. Please use the `predicate` parameter instead.
#   if await self.run_code(code, result, async_=asy):
# /var/folders/nq/qfr1b2_94wsgjv23mrk2bvvm0000gn/T/ipykernel_97253/917092338.py:1: UserWarning: CRS mismatch between the CRS of left geometries and the CRS of right geometries.
# Use `to_crs()` to reproject one of the input geometries to match the CRS of the other.
#
# Left CRS: None
# Right CRS: EPSG:4326
#
#   base = geopandas.sjoin(base_tratada, bog_hogares, how = 'inner', op = 'within')

# %%
base_tratada.head()
# Out:
#   type_data               property_id      price month  year surface_total
# 0         1  4fa04a187235d7509a43a8cf  580000000    10  2020            NA  \
# 1         1  f9cfbb306af543a759c1f3f2  600000000    10  2020            NA
# 2         1  957a84e8e93ae2b33bc6f61b  400000000    10  2020            NA
# 3         1  eb32d75b32bc5e8677207fc7  800000000    10  2020            NA
# 4         1  880a6e7bd74dc2568940d275  480000000    10  2020            NA
#
#   surface_covered rooms bedrooms bathrooms  ...     distancia_mall4
# 0              NA     3        3         2  ...   60131007614.16999  \
# 1              NA     9        9         2  ...  501375907320.27716
# 2              NA     8        8         2  ...   271218506534.5503
# 3              NA     6        6         2  ...   41426798513.02283
# 4              NA     3        3         3  ...  34078366888.784737
#
#   distancia_ciclovia4 ditancia_servecios4  distancia_parques5
# 0  11286605965536.287   4465719020111.951   659018759140.0732  \
# 1  282519114412612.56  15332405542124.877   323315967.0581185
# 2  215558240203799.06  1056509325959.0814  135291964021.55711
# 3   4961285780058.306    58106103339.0209  11264440620562.068
# 4   52842004688979.09   27802897.81502476    114956710744.587
#
#   distancia_restaurante5 distancia_estaciones_tp5     distancia_mall5
# 0      87280740937.83739        17224063665006542    29776462516315.4  \
# 1      825225844019.4675        76398790420468560   421894949176277.2
# 2       1728827069070.78       603114187127478100  195726283749954.62
# 3     394813996044.52637       968463400836554600  18689673524199.098
# 4     210041.87722959128       393770616239102700   14641934771991.92
#
#    distancia_ciclovia5 ditancia_servecios5                   geometry
# 0    20687318658960752    6491786711938846  POINT (-74.09965 4.70721)
# 1  1158269966227056400   30339811085987696  POINT (-74.13164 4.61220)
# 2   825953859256658300  1071128731337901.2  POINT (-74.13866 4.58662)
# 3     7404450003103239  28528385220177.047  POINT (-74.14215 4.67815)
# 4   142470223821240050  2018889639.8258078  POINT (-74.05155 4.75650)
#
# [5 rows x 55 columns]

# %%
print(base.shape) #union
print(bog_hogares.shape) #datos bogota
print(base_tratada.shape) #original
# Out:
# (60837, 62)
# (74199, 7)
# (48930, 55)

# %%
base.head()
# Out:
#       type_data               property_id      price month  year
# 2             1  957a84e8e93ae2b33bc6f61b  400000000    10  2020  \
# 2             1  957a84e8e93ae2b33bc6f61b  400000000    10  2020
# 3             1  eb32d75b32bc5e8677207fc7  800000000    10  2020
# 14986         1  c70f988cac0f162fcbd7a53b  800000000    10  2020
# 3             1  eb32d75b32bc5e8677207fc7  800000000    10  2020
#
#       surface_total surface_covered rooms bedrooms bathrooms  ...
# 2                NA              NA     8        8         2  ...  \
# 2                NA              NA     8        8         2  ...
# 3                NA              NA     6        6         2  ...
# 14986            NA              NA     6        6         2  ...
# 3                NA              NA     6        6         2  ...
#
#       distancia_ciclovia5 ditancia_servecios5                   geometry
# 2      825953859256658300  1071128731337901.2  POINT (-74.13866 4.58662)  \
# 2      825953859256658300  1071128731337901.2  POINT (-74.13866 4.58662)
# 3        7404450003103239  28528385220177.047  POINT (-74.14215 4.67815)
# 14986    7404450003103239  28528385220177.047  POINT (-74.14215 4.67815)
# 3        7404450003103239  28528385220177.047  POINT (-74.14215 4.67815)
#
#       index_right OBJECTID  MANCODIGO AREA_RESID         ANO    SHAPE_AREA
# 2           15279    15932  002408043    5580.03  2022-01-01  3.259573e-07  \
# 2           53495    54615  002408043    5580.00  2021-01-01  3.259573e-07
# 3           24588    23529  006420094    6880.35  2022-01-01  2.577688e-07
# 14986       24588    23529  006420094    6880.35  2022-01-01  2.577688e-07
# 3           62712    62430  006420094    6880.00  2021-01-01  2.577687e-07
#
#       SHAPE_LEN
# 2      0.002531
# 2      0.002531
# 3      0.002078
# 14986  0.002078
# 3      0.002078
#
# [5 rows x 62 columns]

# %%
base.plot(column = 'AREA_RESID', markersize = .5, legend = True)
# Out:
# <Axes: >
